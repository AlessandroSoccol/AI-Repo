# %% [markdown]
# # 03 — Algoritmos Genéticos
#
# **Curso:** Inteligencia Artificial — Optimización
#
# Este notebook contiene ejemplos guiados y actividades para desarrollar en clase.

# %% [markdown]
# ## Objetivos
#
# - representar soluciones mediante cromosomas;
# - implementar selección, cruce y mutación;
# - observar la evolución de una población;
# - analizar el balance entre exploración y explotación.

# %% [markdown]
# ![HillClimbing](https://drive.google.com/uc?export=view&id=1XSZ2ppaVR85ZRJErD0-0tB4aP26ReY5H)

# %% [markdown]
# ## 1. Problema OneMax
#
# Cada individuo es una cadena binaria de longitud $L$. Queremos maximizar el número de unos:
#
# $$
# \text{fitness}(x)=\sum_{i=1}^{L}x_i
# $$
#
# El óptimo global es una cadena formada completamente por unos. Es un problema sencillo, pero permite observar con claridad todos los componentes de un algoritmo genético.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

SEED = 14
random.seed(SEED)
np.random.seed(SEED)


def create_individual(length, rng):
    return [rng.randint(0, 1) for _ in range(length)]


def fitness(individual):
    return sum(individual)


def as_string(individual):
    return ''.join(map(str, individual))

rng = random.Random(SEED)
example = create_individual(20, rng)
print(as_string(example), 'fitness =', fitness(example))
# Out:
# 00111011111010111100 fitness = 13

# %% [markdown]
# ## 2. Selección por torneo
#
# Elegimos varios individuos al azar y seleccionamos el de mayor fitness. El tamaño del torneo controla la **presión de selección**.

# %%
def tournament_selection(population, tournament_size, rng):
    contestants = rng.sample(population, tournament_size)
    return max(contestants, key=fitness).copy()

population = [create_individual(12, rng) for _ in range(8)]
selected = tournament_selection(population, tournament_size=3, rng=rng)
print('Seleccionado:', as_string(selected), 'fitness =', fitness(selected))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 def tournament_selection(population, tournament_size, rng):
#       2     contestants = rng.sample(population, tournament_size)
#       3     return max(contestants, key=fitness).copy()
#       4
# ----> 5 population = [create_individual(12, rng) for _ in range(8)]
#       6 selected = tournament_selection(population, tournament_size=3, rng=rng)
#       7 print('Seleccionado:', as_string(selected), 'fitness =', fitness(selected))
#
# Cell In[2], line 5, in <listcomp>(.0)
# ----> 5 def tournament_selection(population, tournament_size, rng):
#       6     contestants = rng.sample(population, tournament_size)
#       7     return max(contestants, key=fitness).copy()
#
# NameError: name 'create_individual' is not defined

# %% [markdown]
# ## 3. Cruce de un punto
#
# Dos padres intercambian fragmentos de sus cromosomas.

# %%
def one_point_crossover(parent1, parent2, crossover_rate, rng):
    if rng.random() >= crossover_rate:
        return parent1.copy(), parent2.copy()

    point = rng.randint(1, len(parent1) - 1)
    child1 = parent1[:point] + parent2[point:]
    child2 = parent2[:point] + parent1[point:]
    return child1, child2

p1 = [1, 1, 1, 1, 0, 0, 0, 0]
p2 = [0, 0, 0, 0, 1, 1, 1, 1]
c1, c2 = one_point_crossover(p1, p2, 1.0, rng)
print('Padre 1:', as_string(p1))
print('Padre 2:', as_string(p2))
print('Hijo 1 :', as_string(c1))
print('Hijo 2 :', as_string(c2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       8     return child1, child2
#       9
#      10 p1 = [1, 1, 1, 1, 0, 0, 0, 0]
#      11 p2 = [0, 0, 0, 0, 1, 1, 1, 1]
# ---> 12 c1, c2 = one_point_crossover(p1, p2, 1.0, rng)
#      13 print('Padre 1:', as_string(p1))
#      14 print('Padre 2:', as_string(p2))
#      15 print('Hijo 1 :', as_string(c1))
#
# NameError: name 'rng' is not defined

# %% [markdown]
# ## 4. Mutación
#
# Cada bit cambia con probabilidad $p_m$. La mutación introduce diversidad y puede recuperar información genética que desapareció de la población.

# %%
def mutate(individual, mutation_rate, rng):
    child = individual.copy()
    for i in range(len(child)):
        if rng.random() < mutation_rate:
            child[i] = 1 - child[i]
    return child

before = [0] * 20
after = mutate(before, mutation_rate=0.15, rng=rng)
print('Antes  :', as_string(before))
print('Después:', as_string(after))
# Out:
# Antes  : 00000000000000000000
# Después: 00001010000000010001

# %% [markdown]
# ## 5. Algoritmo genético completo
#
# Incluiremos **elitismo**: el mejor individuo pasa directamente a la siguiente generación.

# %%
def genetic_algorithm(
    chromosome_length=40,
    population_size=60,
    generations=100,
    crossover_rate=0.9,
    mutation_rate=None,
    tournament_size=3,
    elitism=True,
    seed=0
):
    if mutation_rate is None:
        mutation_rate = 1 / chromosome_length

    rng = random.Random(seed)
    population = [create_individual(chromosome_length, rng)
                  for _ in range(population_size)]
    history = []

    for generation in range(generations + 1):
        fitnesses = [fitness(ind) for ind in population]
        best_index = int(np.argmax(fitnesses))
        best = population[best_index].copy()

        history.append({
            'generation': generation,
            'best': max(fitnesses),
            'mean': float(np.mean(fitnesses)),
            'diversity': len({tuple(ind) for ind in population}) / population_size,
            'best_individual': best
        })

        if fitness(best) == chromosome_length or generation == generations:
            break

        new_population = [best] if elitism else []

        while len(new_population) < population_size:
            parent1 = tournament_selection(population, tournament_size, rng)
            parent2 = tournament_selection(population, tournament_size, rng)
            child1, child2 = one_point_crossover(parent1, parent2, crossover_rate, rng)
            child1 = mutate(child1, mutation_rate, rng)
            child2 = mutate(child2, mutation_rate, rng)
            new_population.extend([child1, child2])

        population = new_population[:population_size]

    return history[-1]['best_individual'], history

best, history = genetic_algorithm(seed=SEED)
print('Mejor individuo:', as_string(best))
print('Fitness:', fitness(best), '/', len(best))
print('Generaciones ejecutadas:', history[-1]['generation'])
# Out:
# Mejor individuo: 1111111111111111111111111111111111111111
# Fitness: 40 / 40
# Generaciones ejecutadas: 16

# %%
generations = [h['generation'] for h in history]
best_values = [h['best'] for h in history]
mean_values = [h['mean'] for h in history]

plt.figure(figsize=(8, 4))
plt.plot(generations, best_values, label='Mejor fitness')
plt.plot(generations, mean_values, label='Fitness medio')
plt.xlabel('Generación')
plt.ylabel('Fitness')
plt.title('Evolución de la población')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(generations, [h['diversity'] for h in history])
plt.xlabel('Generación')
plt.ylabel('Proporción de individuos únicos')
plt.title('Diversidad de la población')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Efecto de la mutación
#
# Una tasa muy baja puede producir convergencia prematura. Una tasa muy alta destruye las estructuras que el cruce intenta conservar.

# %%
rates = [0.0, 0.005, 0.025, 0.1, 0.5]
summary = []

for rate in rates:
    final_fitness = []
    generations_used = []
    for seed in range(20):
        best, hist = genetic_algorithm(
            chromosome_length=40,
            generations=120,
            mutation_rate=rate,
            seed=seed
        )
        final_fitness.append(fitness(best))
        generations_used.append(hist[-1]['generation'])
    summary.append((rate, np.mean(final_fitness), np.mean(generations_used)))

print('mutation_rate | fitness medio | generaciones medias')
for row in summary:
    print(f'{row[0]:>13.3f} | {row[1]:>13.2f} | {row[2]:>18.2f}')
# Out:
# mutation_rate | fitness medio | generaciones medias
#         0.000 |         37.65 |             114.85
#         0.005 |         40.00 |              19.90
#         0.025 |         40.00 |              16.45
#         0.100 |         38.45 |             117.00
#         0.500 |         31.75 |             120.00

# %% [markdown]
# ## Actividades
#
# ### Actividad 1 — Selección por ruleta
#
# Implementa selección proporcional al fitness. Ten cuidado con poblaciones donde todos los individuos tengan fitness cero.

# %%
def roulette_selection(population, rng):
    fitness_values = [fitness(individual) for individual in population]
    total_fitness = sum(fitness_values)

    if total_fitness == 0:
        return rng.choice(population)

    selected = rng.uniform(0, total_fitness)
    accumulated = 0

    for individual, fit in zip(population, fitness_values):
        accumulated += fit

        if accumulated >= selected:
            return individual

    return population[-1]

# %% [markdown]
# ### Actividad 2 — Cruce uniforme
#
# En cada posición, el hijo toma el gen del padre 1 o del padre 2 con igual probabilidad.

# %%
def uniform_crossover(parent1, parent2, crossover_rate, rng):
    if rng.random() > crossover_rate:
        return parent1.copy(), parent2.copy()

    child1 = []
    child2 = []

    for gene1, gene2 in zip(parent1, parent2):
        if rng.random() < 0.5:
            child1.append(gene1)
            child2.append(gene2)
        else:
            child1.append(gene2)
            child2.append(gene1)

    return child1, child2

# %% [markdown]
# ### Actividad 3 — Frase objetivo
#
# Adapta el algoritmo para evolucionar una cadena hasta alcanzar una frase objetivo, por ejemplo `INTELIGENCIA ARTIFICIAL`.
#
# Sugerencias:
#
# - cromosoma: lista de caracteres;
# - fitness: número de caracteres correctos en la posición correcta;
# - alfabeto: letras, espacio y, opcionalmente, signos de puntuación.

# %%
TARGET = "INTELIGENCIA ARTIFICIAL"
ALPHABET = "ABCDEFGHIJKLMNOPQRSTUVWXYZ "

def create_phrase_individual(rng):
    return [rng.choice(ALPHABET) for _ in range(len(TARGET))]


def phrase_fitness(individual):
    return sum(
        gene == target
        for gene, target in zip(individual, TARGET)
    )


def phrase_selection(population, rng):
    fitness_values = [phrase_fitness(ind) for ind in population]
    total_fitness = sum(fitness_values)

    if total_fitness == 0:
        return rng.choice(population)

    selected = rng.uniform(0, total_fitness)
    accumulated = 0

    for individual, fit in zip(population, fitness_values):
        accumulated += fit

        if accumulated >= selected:
            return individual

    return population[-1]


def phrase_mutation(individual, mutation_rate, rng):
    child = individual.copy()

    for i in range(len(child)):
        if rng.random() < mutation_rate:
            child[i] = rng.choice(ALPHABET)

    return child


def phrase_genetic_algorithm(
    population_size=200,
    generations=5000,
    crossover_rate=0.9,
    mutation_rate=0.05
):
    rng = random.Random(SEED)

    population = [
        create_phrase_individual(rng)
        for _ in range(population_size)
    ]

    for generation in range(generations + 1):
        population.sort(key=phrase_fitness, reverse=True)

        best = population[0]
        best_fitness = phrase_fitness(best)

        if generation % 20 == 0 or best_fitness == len(TARGET):
            print(
                f"Generación {generation}: "
                f"{''.join(best)} "
                f"fitness = {best_fitness}/{len(TARGET)}"
            )

        if best_fitness == len(TARGET):
            return best

        new_population = [best.copy()]

        while len(new_population) < population_size:
            parent1 = phrase_selection(population, rng)
            parent2 = phrase_selection(population, rng)

            child1, child2 = uniform_crossover(
                parent1,
                parent2,
                crossover_rate,
                rng
            )

            child1 = phrase_mutation(child1, mutation_rate, rng)
            child2 = phrase_mutation(child2, mutation_rate, rng)

            new_population.append(child1)

            if len(new_population) < population_size:
                new_population.append(child2)

        population = new_population

    return population[0]


best_phrase = phrase_genetic_algorithm()

print("\nMejor frase encontrada:", ''.join(best_phrase))
# Out:
# Generación 0: TUGRLILBKCIILMQDGTJWBYN fitness = 4/23
# Generación 20: PNQSLIGCOCIF KRTIAICIAL fitness = 15/23
# Generación 40: INTEEIG HFIF GRTIFICIAL fitness = 17/23
# Generación 60: INTEEIG HFIF GRTIFICIAL fitness = 17/23
# Generación 80: INTEEIG HFIF GRTIFICIAL fitness = 17/23
# Generación 100: INTEEIG HFIF GRTIFICIAL fitness = 17/23
# Generación 120: INTELICOUCIA ARTILIMIAL fitness = 18/23
# Generación 140: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 160: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 180: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 200: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 220: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 240: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 260: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 280: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 300: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 320: INTELICBUCIA ARTIFIMIAL fitness = 19/23
# Generación 340: INTELIBECCIA ARTIFNCIAL fitness = 20/23
# Generación 360: INTELIBECCIA ARTIFNCIAL fitness = 20/23
# Generación 380: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 400: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 420: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 440: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 460: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 480: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 500: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 520: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 540: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 560: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 580: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 600: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 620: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 640: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 660: INTALILENCIA ARTIFICIAL fitness = 21/23
# Generación 680: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 700: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 720: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 740: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 760: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 780: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 800: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 820: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 840: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 860: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 880: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 900: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 920: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 940: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 960: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 980: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1000: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1020: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1040: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1060: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1080: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1100: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1120: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1140: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1160: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1180: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1200: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1220: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1240: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1260: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1280: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1300: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1320: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1340: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1360: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1380: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1400: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1420: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1440: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1460: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1480: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1500: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1520: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1540: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1560: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1580: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1600: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1620: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1640: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1660: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1680: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1700: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1720: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1740: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1760: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1780: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1800: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1820: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1840: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1860: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1880: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1900: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1920: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1940: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1960: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 1980: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2000: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2020: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2040: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2060: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2080: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2100: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2120: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2140: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2160: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2180: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2200: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2220: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2240: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2260: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2280: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2300: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2320: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2340: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2360: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2380: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2400: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2420: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2440: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2460: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2480: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2500: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2520: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2540: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2560: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2580: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2600: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2620: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2640: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2660: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2680: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2700: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2720: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2740: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2760: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2780: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2800: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2820: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2840: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2860: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2880: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2900: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2920: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2940: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2960: INTELIGENCIA ARTIFICPAL fitness = 22/23
# Generación 2967: INTELIGENCIA ARTIFICIAL fitness = 23/23
#
# Mejor frase encontrada: INTELIGENCIA ARTIFICIAL

# %% [markdown]
# ### Actividad 4 — Sin elitismo
#
# Ejecuta el algoritmo con y sin elitismo. ¿Puede disminuir el mejor fitness de una generación a la siguiente? Explica el resultado.

# %%
def compare_elitism(
    population_size=80,
    generations=120,
    crossover_rate=0.9,
    mutation_rate=0.08
):
    def run(use_elitism):
        rng = random.Random(SEED)

        population = [
            create_phrase_individual(rng)
            for _ in range(population_size)
        ]

        best_history = []

        for generation in range(generations):
            population.sort(key=phrase_fitness, reverse=True)

            best = population[0]
            best_history.append(phrase_fitness(best))

            new_population = []

            if use_elitism:
                new_population.append(best.copy())

            while len(new_population) < population_size:
                parent1 = phrase_selection(population, rng)
                parent2 = phrase_selection(population, rng)

                child1, child2 = uniform_crossover(
                    parent1,
                    parent2,
                    crossover_rate,
                    rng
                )

                child1 = phrase_mutation(child1, mutation_rate, rng)
                child2 = phrase_mutation(child2, mutation_rate, rng)

                new_population.append(child1)

                if len(new_population) < population_size:
                    new_population.append(child2)

            population = new_population

        return best_history

    with_elitism = run(True)
    without_elitism = run(False)

    decreases_with = sum(
        with_elitism[i] < with_elitism[i - 1]
        for i in range(1, len(with_elitism))
    )

    decreases_without = sum(
        without_elitism[i] < without_elitism[i - 1]
        for i in range(1, len(without_elitism))
    )

    print("Con elitismo:")
    print("Disminuciones del mejor fitness:", decreases_with)

    print("\nSin elitismo:")
    print("Disminuciones del mejor fitness:", decreases_without)

    print("\nMejor fitness final con elitismo:", with_elitism[-1])
    print("Mejor fitness final sin elitismo:", without_elitism[-1])


compare_elitism()
# Out:
# Con elitismo:
# Disminuciones del mejor fitness: 0
#
# Sin elitismo:
# Disminuciones del mejor fitness: 30
#
# Mejor fitness final con elitismo: 15
# Mejor fitness final sin elitismo: 12

# %% [markdown]
# ## Preguntas de cierre
#
# 1. ¿Qué papel cumple la población que no existe en Hill Climbing?
# 2. ¿Por qué el cruce no garantiza hijos mejores que sus padres?
# 3. ¿Qué significa convergencia prematura?
# 4. ¿Qué parámetros controlan la exploración?

# %% [markdown]
# ### Respuestas
#
# 1. **¿Qué papel cumple la población que no existe en Hill Climbing?**
#
#    El algoritmo genético trabaja con una población completa, mientras Hill Climbing sigue una sola solución y sus vecinos. En esta actividad, la población de cadenas de 40 bits permite explorar varias zonas simultáneamente y conservar diversidad mediante selección, cruce y mutación. En OneMax, la población evoluciona buscando la cadena de 40 unos.
#
# 2. **¿Por qué el cruce no garantiza hijos mejores que sus padres?**
#
#    El cruce solo combina genes y no evalúa previamente si la combinación será mejor. Por eso un hijo puede ser mejor, igual o peor que sus padres. Después se calcula `fitness` para que la selección favorezca las cadenas con más unos. En la frase objetivo, combinar caracteres tampoco garantiza aumentar las posiciones correctas.
#
# 3. **¿Qué significa convergencia prematura?**
#
#    Ocurre cuando la población pierde diversidad antes de alcanzar el óptimo global. En OneMax, con mutación `0.0` el fitness medio final fue `37.65/40`, mientras que con `0.005` y `0.025` fue `40/40`. Esto muestra que una mutación moderada puede evitar el estancamiento, aunque una tasa excesiva puede destruir buenas soluciones.
#
# 4. **¿Qué parámetros controlan la exploración?**
#
#    La tasa de mutación, la tasa de cruce, el tamaño de la población, el tamaño del torneo, el número de generaciones y el elitismo. Mutación y poblaciones grandes favorecen la exploración; torneos grandes y elitismo favorecen la explotación. En el experimento, `0.005` y `0.025` lograron `40/40`, mientras `0.5` obtuvo `31.75/40`.
#
# 5. **¿Puede disminuir el mejor fitness sin elitismo?**
#
#    Sí. En la actividad de la frase objetivo, disminuyó `0` veces con elitismo y `30` veces sin elitismo. Con elitismo el mejor individuo se copia a la siguiente generación; sin elitismo puede perderse durante selección, cruce o mutación. El mejor fitness final fue `15` con elitismo y `12` sin elitismo.
